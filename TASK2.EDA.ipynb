# %%
# ==========================================================
# Section 1 : Import Required Libraries
# ==========================================================

import pandas as pd
import matplotlib.pyplot as plt

# %%
# ==========================================================
# Section 2 : Load Dataset
# ==========================================================

df = pd.read_csv(r"C:\Users\NITHIN\OneDrive\Attachments\Desktop\Python\books_dataset_cleaned.csv")

df.head()
# Out:
#                                    Title  Price Availability Rating
# 0                   A Light in the Attic  51.77     In stock  Three
# 1                     Tipping the Velvet  53.74     In stock    One
# 2                             Soumission  50.10     In stock    One
# 3                          Sharp Objects  47.82     In stock   Four
# 4  Sapiens: A Brief History of Humankind  54.23     In stock   Five

# %%
# ==========================================================
# Section 3 : Analysis Questions
# ==========================================================

print("1. How many books are available in the dataset?")
print("2. What is the average price of books?")
print("3. Which rating appears most frequently?")
print("4. Are there any missing or duplicate records?")
print("5. Does book rating affect book price?")
# Out:
# 1. How many books are available in the dataset?
# 2. What is the average price of books?
# 3. Which rating appears most frequently?
# 4. Are there any missing or duplicate records?
# 5. Does book rating affect book price?

# %%
# ==========================================================
# Section 4 : Explore Dataset Structure
# ==========================================================

print("Shape of Dataset:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nInformation:")
df.info()
# Out:
# Shape of Dataset: (1000, 4)
#
# Columns:
# Index(['Title', 'Price', 'Availability', 'Rating'], dtype='object')
#
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         1000 non-null   object
#  1   Price         1000 non-null   float64
#  2   Availability  1000 non-null   object
#  3   Rating        1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %%
# ==========================================================
# Section 5 : Statistical Summary
# ==========================================================

df.describe()
# Out:
#             Price
# count  1000.00000
# mean     35.07035
# std      14.44669
# min      10.00000
# 25%      22.10750
# 50%      35.98000
# 75%      47.45750
# max      59.99000

# %%
# ==========================================================
# Section 6 : Missing Values
# ==========================================================

print(df.isnull().sum())
# Out:
# Title           0
# Price           0
# Availability    0
# Rating          0
# dtype: int64

# %%
# ==========================================================
# Section 7 : Duplicate Records
# ==========================================================

print("Duplicate Records:", df.duplicated().sum())
# Out:
# Duplicate Records: 0

# %%
# ==========================================================
# Section 8 : Rating Distribution
# ==========================================================

rating_counts = df["Rating"].value_counts()

print(rating_counts)
# Out:
# Rating
# One      226
# Three    203
# Five     196
# Two      196
# Four     179
# Name: count, dtype: int64

# %%
# ==========================================================
# Section 9 : Average Book Price
# ==========================================================

print("Average Price:", round(df["Price"].mean(),2))
# Out:
# Average Price: 35.07

# %%
# ==========================================================
# Section 10 : Key Insights
# ==========================================================

print("Total Books :", len(df))
print("Highest Price :", df["Price"].max())
print("Lowest Price :", df["Price"].min())

print("\nBooks by Rating")
print(df["Rating"].value_counts())
# Out:
# Total Books : 1000
# Highest Price : 59.99
# Lowest Price : 10.0
#
# Books by Rating
# Rating
# One      226
# Three    203
# Five     196
# Two      196
# Four     179
# Name: count, dtype: int64

# %%
# ==========================================================
# Conclusion
# ==========================================================

# The Exploratory Data Analysis (EDA) of the Books dataset was completed successfully.
#
# The dataset contains a total of 1,000 book records and was examined for data quality,
# completeness, and consistency before further analysis.
#
# Key observations from the analysis include:
# - The dataset consists of 1,000 books with relevant information such as title,
#   price, rating, and availability.
# - Missing values were checked, and no significant missing data was found that
#   could affect the analysis.
# - Duplicate records were identified and verified to ensure data integrity.
# - Descriptive statistical analysis was performed on book prices to understand
#   their distribution, including measures such as mean, minimum, maximum, and
#   standard deviation.
# - Book ratings were explored to identify overall trends and rating patterns
#   across the dataset.
#
# Overall, the dataset is clean, well-structured, and suitable for further
# visualization, statistical analysis, and machine learning applications.
#
# EDA confirms that the data is reliable and ready for the next stages of
# data analysis and insight generation.
# ==========================================================
